# %%
# %pip install spacy
import spacy
import os
import subprocess

nlp = spacy.load("en_core_web_sm")

texte = "There are courses and laboratory courses. Homeworks are part of courses. Courses are organized by teachers. Teachers are either professors or assistants. Professors teach courses while assistants only teach laboratory courses."
doc = nlp(texte)
# Out:
# Requirement already satisfied: spacy in c:\users\asus vivobook f1605p\appdata\local\programs\python\python312\lib\site-packages (3.8.11)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\asus vivobook f1605p\appdata\local\programs\python\python312\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\asus vivobook f1605p\appdata\local\programs\python\python312\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\asus vivobook f1605p\appdata\local\programs\python\python312\lib\site-packages (from spacy) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\asus vivobook f1605p\appdata\local\programs\python\python312\lib\site-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\asus vivobook f1605p\appdata\local\programs\python\python312\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in c:\users\asus vivobook f1605p\appdata\local\programs\python\python312\lib\site-packages (from spacy) (8.3.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\asus vivobook f1605p\appdata\local\programs\python\python312\lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\asus vivobook f1605p\appdata\local\programs\python\python312\lib\site-packages (from spacy) (2.5.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\asus vivobook f1605p\appdata\local\programs\python\python312\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.4.2 in c:\users\asus vivobook f1605p\appdata\local\programs\python\python312\lib\site-packages (from spacy) (0.4.3)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in c:\users\asus vivobook f1605p\appdata\local\programs\python\python312\lib\site-packages (from spacy) (0.20.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\asus vivobook f1605p\appdata\local\programs\python\python312\lib\site-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\asus vivobook f1605p\appdata\local\programs\python\python312\lib\site-packages (from spacy) (2.0.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\asus vivobook f1605p\appdata\local\programs\python\python312\lib\site-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\asus vivobook f1605p\appdata\local\programs\python\python312\lib\site-packages (from spacy) (2.8.2)
# Requirement already satisfied: jinja2 in c:\users\asus vivobook f1605p\appdata\local\programs\python\python312\lib\site-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\asus vivobook f1605p\appdata\local\programs\python\python312\lib\site-packages (from spacy) (75.6.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\asus vivobook f1605p\appdata\local\programs\python\python312\lib\site-packages (from spacy) (24.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\asus vivobook f1605p\appdata\local\programs\python\python312\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\asus vivobook f1605p\appdata\local\programs\python\python312\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\asus vivobook f1605p\appdata\local\programs\python\python312\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\asus vivobook f1605p\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asus vivobook f1605p\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asus vivobook f1605p\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus vivobook f1605p\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.8.30)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in c:\users\asus vivobook f1605p\appdata\local\programs\python\python312\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.3.3)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\asus vivobook f1605p\appdata\local\programs\python\python312\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: colorama in c:\users\asus vivobook f1605p\appdata\local\programs\python\python312\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\asus vivobook f1605p\appdata\local\programs\python\python312\lib\site-packages (from typer-slim<1.0.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\asus vivobook f1605p\appdata\local\programs\python\python312\lib\site-packages (from weasel<0.5.0,>=0.4.2->spacy) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\asus vivobook f1605p\appdata\local\programs\python\python312\lib\site-packages (from weasel<0.5.0,>=0.4.2->spacy) (7.5.0)
# Requirement already satisfied: wrapt in c:\users\asus vivobook f1605p\appdata\local\programs\python\python312\lib\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.4.2->spacy) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\asus vivobook f1605p\appdata\local\programs\python\python312\lib\site-packages (from jinja2->spacy) (2.1.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
concepts = set()
relations = []

# Extract concepts (nouns and proper nouns)
for token in doc:
    if token.pos_ in ["NOUN", "PROPN"]:
        concepts.add(token.text)

# %%
# Extract relations
relations.append(("Homework", "partOf", "Course"))
relations.append(("LaboratoryCourse", "isTypeOf", "Course"))
relations.append(("Course", "organizedBy", "Teacher"))
relations.append(("LaboratoryCourse", "organizedBy", "Teacher"))
relations.append(("Professor", "isTypeOf", "Teacher"))
relations.append(("Assistant", "isTypeOf", "Teacher"))
relations.append(("Professor", "teaches", "Course"))
relations.append(("Assistant", "teaches", "LaboratoryCourse"))

# Display
print("🔹 Concepts extracted:")
for c in sorted(concepts):
    print("-", c)

print("\n🔹 Relations extracted:")
for s, v, o in relations:
    print(f"{s} --{v}--> {o}")
# Out:
# 🔹 Concepts extracted:
# - Courses
# - Homeworks
# - Professors
# - Teachers
# - assistants
# - courses
# - laboratory
# - part
# - professors
# - teachers
#
# 🔹 Relations extracted:
# Homework --partOf--> Course
# LaboratoryCourse --isTypeOf--> Course
# Course --organizedBy--> Teacher
# LaboratoryCourse --organizedBy--> Teacher
# Professor --isTypeOf--> Teacher
# Assistant --isTypeOf--> Teacher
# Professor --teaches--> Course
# Assistant --teaches--> LaboratoryCourse

# %%
from rdflib import Graph, Namespace, RDF, RDFS

# Create the graph
g = Graph()
EX = Namespace("http://example.org/courses/ontology/")

g.bind("ex", EX)

# ======================
# Classes
# ======================
g.add((EX.Course, RDF.type, RDFS.Class))
g.add((EX.LaboratoryCourse, RDF.type, RDFS.Class))
g.add((EX.Homework, RDF.type, RDFS.Class))
g.add((EX.Teacher, RDF.type, RDFS.Class))
g.add((EX.Professor, RDF.type, RDFS.Class))
g.add((EX.Assistant, RDF.type, RDFS.Class))

# Class hierarchy
g.add((EX.LaboratoryCourse, RDFS.subClassOf, EX.Course))
g.add((EX.Professor, RDFS.subClassOf, EX.Teacher))
g.add((EX.Assistant, RDFS.subClassOf, EX.Teacher))

# ======================
# Properties
# ======================
g.add((EX.partOf, RDF.type, RDF.Property))
g.add((EX.organizedBy, RDF.type, RDF.Property))
g.add((EX.teaches, RDF.type, RDF.Property))

# Domains and ranges
g.add((EX.partOf, RDFS.domain, EX.Homework))
g.add((EX.partOf, RDFS.range, EX.Course))

g.add((EX.organizedBy, RDFS.domain, EX.Course))
g.add((EX.organizedBy, RDFS.range, EX.Teacher))

g.add((EX.teaches, RDFS.domain, EX.Teacher))
g.add((EX.teaches, RDFS.range, EX.Course))
# Out:
# <Graph identifier=Ne36b3fc3954046e4a2e4e7fe069f1e6c (<class 'rdflib.graph.Graph'>)>

# %%
# ======================
# Individuals
# ======================
g.add((EX.MathCourse, RDF.type, EX.Course))
g.add((EX.PhysicsLabCourse, RDF.type, EX.LaboratoryCourse))
g.add((EX.Homework1, RDF.type, EX.Homework))
g.add((EX.ProfessorJohn, RDF.type, EX.Professor))
g.add((EX.AssistantMary, RDF.type, EX.Assistant))

# ======================
# Relationships between individuals
# ======================
g.add((EX.Homework1, EX.partOf, EX.MathCourse))
g.add((EX.MathCourse, EX.organizedBy, EX.ProfessorJohn))
g.add((EX.PhysicsLabCourse, EX.organizedBy, EX.AssistantMary))
g.add((EX.ProfessorJohn, EX.teaches, EX.MathCourse))
g.add((EX.AssistantMary, EX.teaches, EX.PhysicsLabCourse))
# Out:
# <Graph identifier=Ne36b3fc3954046e4a2e4e7fe069f1e6c (<class 'rdflib.graph.Graph'>)>

# %%
g.serialize("ontologie_courses.ttl", format="turtle")
print("File ontologie_courses.ttl created successfully")
# Out:
# File ontologie_courses.ttl created successfully
